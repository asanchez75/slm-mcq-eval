# %%
import pandas as pd
df = pd.read_csv('/content/train_pairs_for_dpo.csv')
df.head()
# Out:
#              id                                             chosen  \
# 0  OIC-155-19-A  Question: Which of the following situations wo...
# 1  OIC-155-19-A  Question: What is the recommended treatment fo...
# 2  OIC-155-19-A  Question: What is the recommended initial trea...
# 3  OIC-195-09-A  Question: What is the primary treatment for Gi...
# 4  OIC-195-09-A  Question: What is the primary treatment for Gi...
#
#                                             rejected  \
# 0  Question: What is the recommended treatment du...
# 1  Question: What is the recommended treatment du...
# 2  Question: What is the recommended treatment du...
# 3  Question: What is the cornerstone of Giant Cel...
# 4  Question: What should be considered when taper...
#
#                  chosen_source                 rejected_source
# 0  gemma_9b_distractor_quality  Llama8B_0.1_distractor_quality
# 1   Llama1b_distractor_quality  Llama8B_0.1_distractor_quality
# 2   phi3.5b_distractor_quality  Llama8B_0.1_distractor_quality
# 3  gemma_9b_distractor_quality  Llama8B_0.1_distractor_quality
# 4  gemma_9b_distractor_quality      Llama1b_distractor_quality

# %%
df.columns
# Out:
# Index(['id', 'chosen', 'rejected', 'chosen_source', 'rejected_source'], dtype='object')

# %%
chosen_part   = (df[['id', 'chosen', 'chosen_source']]
                 .rename(columns={'chosen': 'completion',
                                  'chosen_source': 'source'})
                 .assign(label=True))

rejected_part = (df[['id', 'rejected', 'rejected_source']]
                 .rename(columns={'rejected': 'completion',
                                  'rejected_source': 'source'})
                 .assign(label=False))

# combine and reorder columns ---------------------------------------------
new_df = (pd.concat([chosen_part, rejected_part], ignore_index=True)
            [['id', 'completion', 'label', 'source']])

new_df.head()
# Out:
#              id                                         completion  label  \
# 0  OIC-155-19-A  Question: Which of the following situations wo...   True
# 1  OIC-155-19-A  Question: What is the recommended treatment fo...   True
# 2  OIC-155-19-A  Question: What is the recommended initial trea...   True
# 3  OIC-195-09-A  Question: What is the primary treatment for Gi...   True
# 4  OIC-195-09-A  Question: What is the primary treatment for Gi...   True
#
#                         source
# 0  gemma_9b_distractor_quality
# 1   Llama1b_distractor_quality
# 2   phi3.5b_distractor_quality
# 3  gemma_9b_distractor_quality
# 4  gemma_9b_distractor_quality

# %%
new_df.to_csv('train_dataset_for_kto.csv', index=False)
